# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %%
crude_oil_data = pd.read_csv('crude_oil_data_processed.csv')
crude_oil_data.head(5)
# Out:
#    U.S. Crude Oil   Alabama  Alaska  Arkansas  California  Colorado  Mexico  \
# 0             5138       21     655        17         583        82    1326
# 1             5177       21     640        17         586        81    1372
# 2             5003       21     544        17         588        82    1272
# 3             3974       21     681        16         587        88     242
# 4             4738       21     716        17         586        86     803
#
#    Pacific  Florida  Idaho  ...  Pennsylvania  South Dakota  Wyoming  \
# 0       67        5      0  ...             8             5      144
# 1       61        6      0  ...             8             5      145
# 2       70        5      0  ...             8             5      145
# 3       67        5      0  ...             8             5      144
# 4       66        6      0  ...             8             5      145
#
#    West Virginia  Utah  Texas  Tennessee        Date  Year  Month
# ...

# %%
crude_oil_data['Date'] = pd.to_datetime(crude_oil_data['Date'])
crude_oil_data['Date'].head()
# Out:
# 0   2008-06-01
# 1   2008-07-01
# 2   2008-08-01
# 3   2008-09-01
# 4   2008-10-01
# Name: Date, dtype: datetime64[ns]

# %%
crude_oil_data.columns
# Out:
# Index(['U.S. Crude Oil ', 'Alabama', 'Alaska', 'Arkansas', 'California',
#        'Colorado', 'Mexico', 'Pacific', 'Florida', 'Idaho', 'Illinois',
#        'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Mississippi',
#        'Missouri', 'Nebraska', 'Montana', 'Nevada', 'New Mexico', 'New York',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Pennsylvania', 'South Dakota',
#        'Wyoming', 'West Virginia', 'Utah', 'Texas', 'Tennessee', 'Date',
#        'Year', 'Month'],
#       dtype='object')

# %%
crude_oil_data.plot(x='Date', y='U.S. Crude Oil ', figsize=(12,8), color='brown')
plt.ylabel('Production')
plt.title('U.S. Crude Oil Production')
# Out:
# Text(0.5, 1.0, 'U.S. Crude Oil Production')

# %%
crude_oil_data.boxplot('U.S. Crude Oil ', figsize=(12,8)) #best viz to use to view summary descriptive statistics for dataset is boxplot
plt.ylabel('Production')
plt.title('U.S. Crude Oil Production')
# Out:
# Text(0.5, 1.0, 'U.S. Crude Oil Production')

# %%
crude_oil_data.boxplot('California', figsize=(12,8)) #other syntax: crude_oil_data[['California']].boxplot(figsize=(12,8))
plt.ylabel('Production in California')
plt.title('California Crude Oil Production')
# Out:
# Text(0.5, 1.0, 'California Crude Oil Production')

# %%
crude_oil_data[['Alaska', 'California']].boxplot(figsize=(12,8))
plt.ylabel('Production in Alaska and California')
plt.title('Alaska and California Crude Oil Production')
# Out:
# Text(0.5, 1.0, 'Alaska and California Crude Oil Production')

# %%
crude_oil_data.boxplot('U.S. Crude Oil ', by=['Year'], figsize=(12,8))
plt.ylabel('Production')
# Out:
# Text(0, 0.5, 'Production')

# %%
year_data = crude_oil_data.groupby('Year', as_index = False).sum() #as_index=False will ensure col 'Year' does not become the index

# %%
colors=['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10']
year_data.plot.bar(x='Year', y='U.S. Crude Oil ', figsize=(12,8), color=colors)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
crude_oil_data
# Out:
#      U.S. Crude Oil   Alabama  Alaska  Arkansas  California  Colorado  Mexico  \
# 0               5138       21     655        17         583        82    1326
# 1               5177       21     640        17         586        81    1372
# 2               5003       21     544        17         588        82    1272
# 3               3974       21     681        16         587        88     242
# 4               4738       21     716        17         586        86     803
# ..               ...      ...     ...       ...         ...       ...     ...
# 116            10248       17     513        14         463       428    1704
# 117            10461       17     512        14         462       428    1681
# 118            10475       17     497        14         465       447    1583
# 119            10443       16     496        14         464       447    1504
# 120            10674       16     451        14         462       423    1658
#
# ...

# %%
mean_prod_data = crude_oil_data.mean()[1:-3]
mean_prod_data
# Out:
# C:\Users\sspra\AppData\Local\Temp/ipykernel_70996/79581683.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_prod_data = crude_oil_data.mean()[1:-3]
# Alabama            22.958678
# Alaska            540.404959
# Arkansas           16.462810
# California        536.388430
# Colorado          212.115702
# Mexico           1444.264463
# Pacific            43.115702
# Florida             5.190083
# Idaho               0.066116
# Illinois           25.008264
# Indiana             5.619835
# Kansas            114.520661
# Kentucky            7.041322
# Louisiana         177.404959
# Michigan           18.016529
# Mississippi        62.355372
# Missouri            0.223140
# Nebraska            6.966942
# Montana            71.537190
# Nevada              1.000000
# New Mexico        305.495868
# New York            1.000000
# North Dakota      746.380165
# ...

# %%
mean_prod_data = mean_prod_data.sort_values(ascending=False) #sort_values syntax has 'ascending'
mean_prod_data
# Out:
# Texas            2403.826446
# Mexico           1444.264463
# North Dakota      746.380165
# Alaska            540.404959
# California        536.388430
# Oklahoma          321.611570
# New Mexico        305.495868
# Colorado          212.115702
# Wyoming           180.429752
# Louisiana         177.404959
# Kansas            114.520661
# Utah               85.148760
# Montana            71.537190
# Mississippi        62.355372
# Pacific            43.115702
# Ohio               33.322314
# Illinois           25.008264
# Alabama            22.958678
# Michigan           18.016529
# West Virginia      16.471074
# Arkansas           16.462810
# Pennsylvania       13.876033
# Kentucky            7.041322
# Nebraska            6.966942
# Indiana             5.619835
# Florida             5.190083
# South Dakota        4.504132
# Nevada              1.000000
# New York            1.000000
# Missouri            0.223140
# Idaho               0.066116
# dtype: float64

# %%
mean_prod_df = pd.DataFrame(mean_prod_data).reset_index()
mean_prod_df.columns = ['State', 'Production']
mean_prod_df.head(10)
# Out:
#           State   Production
# 0         Texas  2403.826446
# 1        Mexico  1444.264463
# 2  North Dakota   746.380165
# 3        Alaska   540.404959
# 4    California   536.388430
# 5      Oklahoma   321.611570
# 6    New Mexico   305.495868
# 7      Colorado   212.115702
# 8       Wyoming   180.429752
# 9     Louisiana   177.404959

# %%
plt.figure(figsize=(12,8))
plt.bar(mean_prod_df['State'], mean_prod_df['Production'], width = 0.85)
plt.title('US Oil Mean-Production June 2008 to June 2018')
plt.xticks(rotation=90)
#plt.yticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Production')
# Out:
# Text(0, 0.5, 'Production')

# %%
mean_prod_df['Production'].plot.kde(figsize=(12,8)) #KDE (Kernel Density Estimation)
plt.xlabel('Oil Production')
plt.title('US Oil Production June 2008 to June 2018')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(crude_oil_data['Texas'], crude_oil_data['U.S. Crude Oil '], c='g') #'g' is for Green
plt.xlabel('Texas Production')
plt.ylabel('US Production')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(crude_oil_data['California'], crude_oil_data['U.S. Crude Oil '], c='y')
plt.ylabel('US Production')
plt.xlabel('California')
# Out:
# Text(0.5, 0, 'California')

# %%
plt.figure(figsize=(12,8))
plt.scatter(crude_oil_data['Michigan'], crude_oil_data['U.S. Crude Oil '], c='y')
plt.ylabel('US Production')
plt.xlabel('Michigan')
# Out:
# Text(0.5, 0, 'Michigan')
